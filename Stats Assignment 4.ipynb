# %% [markdown]
# #### 1.	Is it possible that an event is independent of itself? If so, when?

# %% [markdown]
# #### 2.	Is it always true that if A and B are independent events, then Ac and Bc are independent events? Show that it is, or give ma counterexample.m

# %% [markdown]
# ![Assignment_4_1.jpg](attachment:Assignment_4_1.jpg)

# %% [markdown]
# ![Assignment_4_2.jpg](attachment:Assignment_4_2.jpg)
